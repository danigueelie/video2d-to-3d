# %%
import torch

print(torch.__version__)
print(torch.cuda.is_available())
# print(torch.cuda.get_device_name(0))
# Out:
# 2.10.0+cpu
# False

# %%
# !python main.py --input data/input.mp4 --stabilize --model_size small
# !python main.py --input data/input.mp4 --mode heatmap --stabilize --stabilizer_type optical_flow --inpaint
# Out:
# Chargement de depth-anything/Depth-Anything-V2-Small-hf...
# Vidéo finale avec audio : outputs\input_depthanything_optical_flow_visu.mp4
# 10:40:29 - Source: 1920x1080 @ 25.0fps
# 10:40:29 - HTTP Request: HEAD https://huggingface.co/depth-anything/Depth-Anything-V2-Small-hf/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# 10:40:30 - HTTP Request: HEAD https://huggingface.co/depth-anything/Depth-Anything-V2-Small-hf/resolve/main/preprocessor_config.json "HTTP/1.1 307 Temporary Redirect"
# ...
# 10:40:30 - Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 10:40:30 - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/depth-anything/Depth-Anything-V2-Small-hf/5426e4f0f36572d16453bbda7a8389317b1bef99/preprocessor_config.json "HTTP/1.1 200 OK"
# ...

# %%
# !python main.py --input data/input.mp4 --mode heatmap --stabilize --stabilizer_type ema --inpaint
# Out:
# Chargement de depth-anything/Depth-Anything-V2-Small-hf...
# Vidéo finale avec audio : outputs\input_depthanything_ema_visu.mp4
# 10:56:19 - Source: 1920x1080 @ 25.0fps
# 10:56:19 - HTTP Request: HEAD https://huggingface.co/depth-anything/Depth-Anything-V2-Small-hf/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# 10:56:20 - HTTP Request: HEAD https://huggingface.co/depth-anything/Depth-Anything-V2-Small-hf/resolve/main/preprocessor_config.json "HTTP/1.1 307 Temporary Redirect"
# 10:56:20 - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/depth-anything/Depth-Anything-V2-Small-hf/5426e4f0f36572d16453bbda7a8389317b1bef99/preprocessor_config.json "HTTP/1.1 200 OK"
# ...

# %%
# !python main.py --input data/input.mp4 --mode heatmap --inpaint
# Out:
# Chargement de depth-anything/Depth-Anything-V2-Small-hf...
# Vidéo finale avec audio : outputs\input_depthanything_raw_visu.mp4
# 11:05:56 - Source: 1920x1080 @ 25.0fps
# 11:05:56 - HTTP Request: HEAD https://huggingface.co/depth-anything/Depth-Anything-V2-Small-hf/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# 11:05:57 - HTTP Request: HEAD https://huggingface.co/depth-anything/Depth-Anything-V2-Small-hf/resolve/main/preprocessor_config.json "HTTP/1.1 307 Temporary Redirect"
# 11:05:57 - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/depth-anything/Depth-Anything-V2-Small-hf/5426e4f0f36572d16453bbda7a8389317b1bef99/preprocessor_config.json "HTTP/1.1 200 OK"
# ...

# %%
# !python main.py --input data/BOOM2.mp4 --mode vr180 --stabilize --inpaint
# Out:
# Chargement de depth-anything/Depth-Anything-V2-Small-hf...
# Vidéo finale avec audio : outputs\BOOM2_depthanything_vr180_ema.mp4
# 11:46:19 - 🎞️ Source: 1920x804 @ 24.0fps | Mode: VR180
# 11:46:19 - HTTP Request: HEAD https://huggingface.co/depth-anything/Depth-Anything-V2-Small-hf/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# ...
# 11:46:19 - Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 11:46:19 - HTTP Request: HEAD https://huggingface.co/depth-anything/Depth-Anything-V2-Small-hf/resolve/main/preprocessor_config.json "HTTP/1.1 307 Temporary Redirect"
# 11:46:19 - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/depth-anything/Depth-Anything-V2-Small-hf/5426e4f0f36572d16453bbda7a8389317b1bef99/preprocessor_config.json "HTTP/1.1 200 OK"
# ...

# %%
# !python main.py --input data/BOOM2.mp4 --mode vr360 --stabilize --inpaint
# Out:
# Chargement de depth-anything/Depth-Anything-V2-Small-hf...
# 12:21:35 - 🎞️ Source: 1920x804 @ 24.0fps | Mode: VR360
# 12:21:35 - HTTP Request: HEAD https://huggingface.co/depth-anything/Depth-Anything-V2-Small-hf/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# 12:21:36 - HTTP Request: HEAD https://huggingface.co/depth-anything/Depth-Anything-V2-Small-hf/resolve/main/preprocessor_config.json "HTTP/1.1 307 Temporary Redirect"
# 12:21:36 - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/depth-anything/Depth-Anything-V2-Small-hf/5426e4f0f36572d16453bbda7a8389317b1bef99/preprocessor_config.json "HTTP/1.1 200 OK"
# The image processor of type `DPTImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# ...

# %%
# !python main.py --input data/input.mp4 --mode vr360 --stabilize --inpaint --divergence 3.0
# Out:
# Chargement de depth-anything/Depth-Anything-V2-Small-hf...
# 13:29:19 - 🎞️ Source: 1920x804 @ 24.0fps | Mode: VR360
# 13:29:20 - HTTP Request: HEAD https://huggingface.co/depth-anything/Depth-Anything-V2-Small-hf/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# 13:29:20 - HTTP Request: HEAD https://huggingface.co/depth-anything/Depth-Anything-V2-Small-hf/resolve/main/preprocessor_config.json "HTTP/1.1 307 Temporary Redirect"
# 13:29:20 - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/depth-anything/Depth-Anything-V2-Small-hf/5426e4f0f36572d16453bbda7a8389317b1bef99/preprocessor_config.json "HTTP/1.1 200 OK"
# The image processor of type `DPTImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# ...
